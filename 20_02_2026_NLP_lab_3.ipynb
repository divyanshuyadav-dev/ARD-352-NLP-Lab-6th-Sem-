# %% [markdown]
# # Experiment 3

# %%
import nltk

from nltk.tokenize import word_tokenize

nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt_tab to /home/div/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/div/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
text = "They are the drinking water"

tokens = word_tokenize(text)

tagged = nltk.pos_tag(tokens)

print(tagged)
# Out:
# [('They', 'PRP'), ('are', 'VBP'), ('the', 'DT'), ('drinking', 'NN'), ('water', 'NN')]

# %%
# chunking
grammer = "NP: {<DT>?<JJ>*<NN>}" 
chunk_parser= nltk.RegexpParser(grammer)

# %%
tree = chunk_parser.parse(tagged)
tree
# Out:
# Tree('S', [('They', 'PRP'), ('are', 'VBP'), Tree('NP', [('the', 'DT'), ('drinking', 'NN')]), Tree('NP', [('water', 'NN')])])

# %%
# Chinking

garmmer = '''Chunk: {<.*>+}
}<DT>{'''

# %%
# chunk phraser
chunk_parser = nltk.RegexpParser(grammer)

# %%
tree = chunk_parser.parse(tagged)
tree
# Out:
# Tree('S', [('They', 'PRP'), ('are', 'VBP'), Tree('NP', [('the', 'DT'), ('drinking', 'NN')]), Tree('NP', [('water', 'NN')])])

# %%
text = "What is on yout mind?"

token = word_tokenize(text)
tagged = nltk.pos_tag(tokens)

# %%
nltk.download("words")
nltk.download("maxent_ne_chunker_tab")
# Out:
# [nltk_data] Downloading package words to /home/div/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /home/div/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# True

# %%
tree = nltk.chunk.ne_chunk(tagged)
tree
# Out:
# Tree('S', [('They', 'PRP'), ('are', 'VBP'), ('the', 'DT'), ('drinking', 'NN'), ('water', 'NN')])

# %%
tree = nltk.chunk.ne_chunk(tagged, binary = True)
tree
# Out:
# Tree('S', [('They', 'PRP'), ('are', 'VBP'), ('the', 'DT'), ('drinking', 'NN'), ('water', 'NN')])

# %%
for node in tree:
    # if hasattr(node, "label"):
    print(node.label, ":", " ".join(i[0] for i in node))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 3
#       1 for node in tree:
#       2     # if hasattr(node, "label"):
# ----> 3     print(node.label, ":", " ".join(i[0] for i in node))
#
# AttributeError: 'tuple' object has no attribute 'label'
